# %% [markdown]
# <a href="https://colab.research.google.com/github/DoctorVinay8097/DV-lab/blob/main/DV_lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Implementation of Back Propagation for Logistic Regression**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Implementing logistic regression with backpropagation involves building a binary classification model that predicts probabilities for two classes (usually 0 and 1). Here are the steps required for implementation.
#
#
#
# 1.   Data Preprocessing
# 2.   Define the Sigmoid Function
# 3.   Initialize Parameters
# 4.   Forward Propagation
# 5.   Compute Loss (Cost) Function
# 6.   Backpropagation
# 7.   Training
# 8.   Prediction
# 9.   Model Evaluation
# 10.  Tuning of hyper-parameters

# %% [markdown]
# ## **1. Data Preprocessing**
# * Obtain your dataset and split it into training and testing sets.
# * Normalize or standardize the features to ensure numerical stability.

# %%
# Write your code
# Generate dummy data using Numpy.
# The dataset should have atleast 2 features and 10 examples
# Similarly generate the y-labels for each example

# %% [markdown]
# ## **2. Implement the sigmoid activation function**
# * The sigmoid function (also called the logistic function) maps any real value to the range (0, 1).
# * It's used as the activation function for the output layer to produce probabilities.
# * The sigmoid function is defined as:
# sigmoid(z) = 1 / (1 + exp(-z))

# %%
# Write your code here
# Define a function which takes the parameter z and returns the sigmoid of that.
# z can be scalar or vector

# %% [markdown]
# ## **3. Initialize Parameters**
# * Initialize the model's parameters: the weights (coefficients) and bias (intercept) to small random values.
# * For logistic regression, you'll have one weight per feature and one bias term.

# %%
## Write your code here
# Define a function which takes the number of features as input and return the weights and bias.

# %% [markdown]
# ## **4. Forward Propagation**
# * Implement the forward propagation process to calculate the predicted probabilities.
# * Compute the linear function z by multiplying the features with their respective weights and adding the bias term.
# * Pass z through the sigmoid function to obtain the predicted probabilities.

# %%
# Write your code here
# Define a function which returns the y-predicted by taking weights, bias and the
# input features X as inputs

# %% [markdown]
# ## **5. Compute Loss (Cost) Function**
# * Use a suitable loss function to measure the difference between the predicted probabilities and the true labels.
# * For binary classification, the cross-entropy (log loss) is commonly used as the loss function.

# %%
# Write your code here.
# Define the function cost using y-actual and y-predicted and return the overall cost
# of the model

# %% [markdown]
# ## **6. Backpropagation**
# * Calculate the gradients of the parameters (weights and bias) with respect to the loss function.
# * Update the parameters using these gradients to minimize the loss function through gradient descent.
# * The gradients are computed using the chain rule and the derivative of the sigmoid function.

# %%
# Write your code here
# Define a function which takes input features X, y-actual and y-predicted to find the
# gradients for weights and biases

# %% [markdown]
# ## **7. Training the model**
# * Run the training process for a fixed number of epochs (iterations) or until convergence.
# * In each epoch, perform forward propagation, compute the loss, and then backpropagate to update the parameters.

# %%
# Write you code
# Define a function which takes input features X, y-actual, num_of_epochs and learning rate
# as input and train the weights and bias.
# The weights and bias will be updated num_of_epochs times, leading to minimum J

# %% [markdown]
# ## **8. Prediction**
# * After training, use the trained parameters to make predictions on new data.
# * Apply the learned weights and bias to the input features and pass them through the sigmoid function to get the probabilities.
# * Classify the examples as class 1 (probability >= 0.5) or class 0 (probability < 0.5).

# %%
# Write your code here
# Define a function to predict the y for given input features

# %% [markdown]
# ## **9. Model Evaluation**
# Evaluate the performance of your logistic regression model on a separate test dataset.

# %%
# Write your code

# %% [markdown]
# ## **10. Regularization**
# * Learning rate
# * num_of_epochs

# %%
# Write your code
